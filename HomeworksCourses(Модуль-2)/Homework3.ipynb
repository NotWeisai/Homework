# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'Planet Name': ['Меркурий', 'Венера', 'Земля', 'Марс', 'Юпитер', 'Сатурн', 'Уран', 'Нептун'],
        'Diameter(km)': [4879, 12104, 12756, 6756, 142984, 120536, 51118, 49528],
        'Rotation Period(In Earth Days)': [58.66, 243, 1, 1.03, 0.42, 0.45, 0.71, 0.67],
        'Revolution Periods(In Earth Days)': [88, 224, 365.25, 687, 4332, 10775, 30681, 60193],
        'Surface Composition': ['Каменистый', 'Каменистый', 'Каменистый', 'Каменистый', 'Газовый', 'Газовый', 'Газовый', 'Газовый'],
        'Moons': [0, 0, 1, 2, 60, 31, 27, 13],
        'Rings': ['Отсутствуют', 'Отсутствуют', 'Отсутствуют', 'Отсутствуют', 'Присутствуют', 'Присутствуют', 'Присутствуют', 'Присутствуют']})
df.head(3)
# Out:
#   Planet Name  Diameter(km)  Rotation Period(In Earth Days)  \
# 0    Меркурий          4879                           58.66
# 1      Венера         12104                          243.00
# 2       Земля         12756                            1.00
#
#    Revolution Periods(In Earth Days) Surface Composition  Moons        Rings
# 0                              88.00          Каменистый      0  Отсутствуют
# 1                             224.00          Каменистый      0  Отсутствуют
# 2                             365.25          Каменистый      1  Отсутствуют

# %%
df.tail(3)
# Out:
#   Planet Name  Diameter(km)  Rotation Period(In Earth Days)  \
# 5      Сатурн        120536                            0.45
# 6        Уран         51118                            0.71
# 7      Нептун         49528                            0.67
#
#    Revolution Periods(In Earth Days) Surface Composition  Moons         Rings
# 5                            10775.0             Газовый     31  Присутствуют
# 6                            30681.0             Газовый     27  Присутствуют
# 7                            60193.0             Газовый     13  Присутствуют

# %%
df.to_csv('Planets.csv', index=False)

# %%
pd.read_csv('/content/Planets.csv')
# Out:
#   Planet Name  Diameter(km)  Rotation Period(In Earth Days)  \
# 0    Меркурий          4879                           58.66
# 1      Венера         12104                          243.00
# 2       Земля         12756                            1.00
# 3        Марс          6756                            1.03
# 4      Юпитер        142984                            0.42
# 5      Сатурн        120536                            0.45
# 6        Уран         51118                            0.71
# 7      Нептун         49528                            0.67
#
#    Revolution Periods(In Earth Days) Surface Composition  Moons         Rings
# 0                              88.00          Каменистый      0   Отсутствуют
# 1                             224.00          Каменистый      0   Отсутствуют
# 2                             365.25          Каменистый      1   Отсутствуют
# 3                             687.00          Каменистый      2   Отсутствуют
# ...
